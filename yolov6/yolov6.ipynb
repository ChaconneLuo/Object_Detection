# %%
# Download MT-YOLOv6 repository and install requirements
# !git clone https://github.com/meituan/YOLOv6
# %cd YOLOv6
# %pip install -r requirements.txt
# Out:
# Cloning into 'YOLOv6'...
# remote: Enumerating objects: 3838, done.
# remote: Counting objects: 100% (1711/1711), done.
# remote: Compressing objects: 100% (329/329), done.
# remote: Total 3838 (delta 1502), reused 1396 (delta 1382), pack-reused 2127
# Receiving objects: 100% (3838/3838), 47.12 MiB | 37.93 MiB/s, done.
# Resolving deltas: 100% (2340/2340), done.
# /kaggle/working/YOLOv6
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.2/426.2 kB 3.6 MB/s eta 0:00:00a 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 25.1 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="1gBpoxVirzj0NHBuskuN")
project = rf.workspace("tan-vrfq5").project("detect-fire-hjvcj")
version = project.version(2)
dataset = version.download("mt-yolov6")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 1.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 3.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 30.0 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
# ...

# %%
# !python tools/train.py --batch 64 --conf configs/yolov6s.py --epochs 12 --img-size 640 --data {dataset.location}/data.yaml --device 0,1
# Out:
# 2024-05-03 06:56:26.995340: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-03 06:56:26.995448: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-03 06:56:27.093555: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 0 image(s) corrupted: 100%|███████████████| 6241/6241 [00:01<00:00, 4015.71it/s]
# 6241 label(s) found, 0 label(s) missing, 0 label(s) empty, 0 invalid label files
# 0 image(s) corrupted: 100%|███████████████| 1660/1660 [00:00<00:00, 2387.05it/s]
# 1660 label(s) found, 0 label(s) missing, 0 label(s) empty, 0 invalid label files
# ...

# %%
import glob
from IPython.display import Image, display

i = 0
limit = 3 # max images to print
for imageName in glob.glob('./runs/train/exp/*.jpg'): #assuming JPG
    if i < limit:
      display(Image(filename=imageName))
      print("\n\n")
    i = i + 1
